# %% [markdown]
# # Dataset Exploration
#
# This notebook explores the structure and contents of the dataset.

# %%
import scipy.io
import numpy as np
import pandas as pd
import os

# Load the dataset
mat_path = '../data/raw/Data_structure_all_subs.mat'
mat_data = scipy.io.loadmat(mat_path)

# %%
# Display all keys
print("Keys in the dataset:")
for key in mat_data.keys():
    if not key.startswith('__'):
        print(f"  - {key}")
